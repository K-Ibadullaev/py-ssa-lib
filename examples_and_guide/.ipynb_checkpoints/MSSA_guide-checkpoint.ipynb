# %% [markdown]
# # MSSA Guide

# %% [markdown]
# ## Load Data Set
# This data set contains the data anout the energy consumption for 5 Countries from 1991 to 2008 and available via load_ method

# %%
# import sys
# !{sys.executable} -m pip install py_ssa_lib

# %%
from py_ssa_lib.datasets.load_energy_consumption_df import load_energy_consumption_df

# %%
df = load_energy_consumption_df(rawDS=False)

# %%
df
# Out:
#    Unnamed: 0      Country      1991      1992      1993      1994      1995  \
# 0           0       France   9.73804   9.79360   9.80209   9.78123  10.05206
# 1           1       Canada  11.11733  11.46716  11.70631  12.02414  12.21325
# 2           2      Germany  14.29970  14.03830  14.07232  14.01249  14.38346
# 3           3        China  28.15790  29.26608  30.03294  34.11046  34.75640
# 4           4  Netherlands   3.49513   3.46788   3.53898   3.50781   3.57542
#
#        1996      1997      1998      1999      2000      2001      2002  \
# 0  10.42370  10.36194  10.58991  10.71493  10.85032  11.08966  10.99795
# 1  12.56482  12.66968  12.35699  12.97692  13.07669  12.87847  13.10786
# 2  14.39479  14.34024  14.32692  14.10906  14.26147  14.61945  14.32545
# 3  35.55399  37.74732  37.03964  36.51251  36.35203  38.41214  43.90988
# 4   3.73327   3.69939   3.69151   3.68246   3.79417   3.92984   3.93964
#
#        2003      2004      2005      2006      2007      2008
# 0  11.11784  11.30309  11.35252  11.37692  11.19392  11.29033
# 1  13.52061  13.83128  14.16374  13.81736  14.07179  14.02923
# 2  14.58721  14.70148  14.39950  14.65476  14.18592  14.35692
# 3  51.15543  62.91903  68.24567  72.89060  78.00135  85.05974
# 4   4.00102   4.11195   4.22233   4.13898   4.37748   4.32717

# %% [markdown]
# We get rid of unwanted columns

# %%
df = df.iloc[:,1:]

# %%
df
# Out:
#        Country      1991      1992      1993      1994      1995      1996  \
# 0       France   9.73804   9.79360   9.80209   9.78123  10.05206  10.42370
# 1       Canada  11.11733  11.46716  11.70631  12.02414  12.21325  12.56482
# 2      Germany  14.29970  14.03830  14.07232  14.01249  14.38346  14.39479
# 3        China  28.15790  29.26608  30.03294  34.11046  34.75640  35.55399
# 4  Netherlands   3.49513   3.46788   3.53898   3.50781   3.57542   3.73327
#
#        1997      1998      1999      2000      2001      2002      2003  \
# 0  10.36194  10.58991  10.71493  10.85032  11.08966  10.99795  11.11784
# 1  12.66968  12.35699  12.97692  13.07669  12.87847  13.10786  13.52061
# 2  14.34024  14.32692  14.10906  14.26147  14.61945  14.32545  14.58721
# 3  37.74732  37.03964  36.51251  36.35203  38.41214  43.90988  51.15543
# 4   3.69939   3.69151   3.68246   3.79417   3.92984   3.93964   4.00102
#
#        2004      2005      2006      2007      2008
# 0  11.30309  11.35252  11.37692  11.19392  11.29033
# 1  13.83128  14.16374  13.81736  14.07179  14.02923
# 2  14.70148  14.39950  14.65476  14.18592  14.35692
# 3  62.91903  68.24567  72.89060  78.00135  85.05974
# 4   4.11195   4.22233   4.13898   4.37748   4.32717

# %% [markdown]
# ### Split Data into Train and Test Sets

# %% [markdown]
# We left out some M records to use them as test data

# %%
import pandas as pd

# %%
M = 3
train_df = df.iloc[:,:-M]
train_df
# Out:
#        Country      1991      1992      1993      1994      1995      1996  \
# 0       France   9.73804   9.79360   9.80209   9.78123  10.05206  10.42370
# 1       Canada  11.11733  11.46716  11.70631  12.02414  12.21325  12.56482
# 2      Germany  14.29970  14.03830  14.07232  14.01249  14.38346  14.39479
# 3        China  28.15790  29.26608  30.03294  34.11046  34.75640  35.55399
# 4  Netherlands   3.49513   3.46788   3.53898   3.50781   3.57542   3.73327
#
#        1997      1998      1999      2000      2001      2002      2003  \
# 0  10.36194  10.58991  10.71493  10.85032  11.08966  10.99795  11.11784
# 1  12.66968  12.35699  12.97692  13.07669  12.87847  13.10786  13.52061
# 2  14.34024  14.32692  14.10906  14.26147  14.61945  14.32545  14.58721
# 3  37.74732  37.03964  36.51251  36.35203  38.41214  43.90988  51.15543
# 4   3.69939   3.69151   3.68246   3.79417   3.92984   3.93964   4.00102
#
#        2004      2005
# 0  11.30309  11.35252
# 1  13.83128  14.16374
# 2  14.70148  14.39950
# 3  62.91903  68.24567
# 4   4.11195   4.22233

# %%
test_df = pd.concat([df.iloc[:,0],df.iloc[:,-M:]], axis=1)
test_df
# Out:
#        Country      2006      2007      2008
# 0       France  11.37692  11.19392  11.29033
# 1       Canada  13.81736  14.07179  14.02923
# 2      Germany  14.65476  14.18592  14.35692
# 3        China  72.89060  78.00135  85.05974
# 4  Netherlands   4.13898   4.37748   4.32717

# %% [markdown]
# ##  MSSA

# %% [markdown]
# ### Setup

# %% [markdown]
# We start with the import of the class MSSA

# %%
from py_ssa_lib.MSSA import MSSA

# %% [markdown]
# Then it is necessary to define the parameters for the MSSA

# %%
idx_start = 1 # the index of the first column where time series begin
window_size = 7 # the most important parameter of the MSSA, also denoted as L in the literature
decomposition = "svd" # for svd decomposition use either "svd", or "rand_svd" for full and approximated svd decomposition

# %% [markdown]
# The window size $L$ is the most important parameter as it defines the size of the trajectory matrices. This matrix is essential and is decomposed using the $SVD$ Decomposition. The corresponding parameter allows to choose between the full $SVD$ which outputs all eigenvalues and eigenvectors, and **randomized SVD**, which preserves only the $L/2 - L/3 - 1$ largest eigenvalues and is extremely useful when the time series is large, e.g $N$ or $M$ > 100, where $N$ is a number of columns containing nummeric value/record for the time step in the time series (here, $N=18 - M$), $M$ is number of left out test records  and  $S$-number of times series in the data set (here, $S=5$)

# %% [markdown]
# ### Fit MSSA to the Dataset

# %% [markdown]
# Now we are set to initialize and fit our MSSA on th data set

# %%
# mssa_inst = MSSA(Verbose=True) # uncomment this section to output inner parameters of the instance
mssa_inst = MSSA()
mssa_inst.fit(df=train_df, L=window_size, decomposition=decomposition, idx_start_ts=idx_start )

# %% [markdown]
# ### Grouping Components for the Reconstruction

# %% [markdown]
# There are 2 methods available for the grouping of eigentriples and consequently, the elementary matrices. These are used for the reconstruction of the particular components of the fited time series.
# Both of them are visual:

# %% [markdown]
# #### Inspect the Behaviour of the Lefthand-side Eigenvectors $U$ and the Contribution of the Corresponding Eigenvalues

# %%
mssa_inst.plot_eigenvals_contribution()

# %% [markdown]
# Generally, $U$ can consist of a large number of column vectors, so for the better visualization it is better to limit number of displayed eigenvectors.
#
# The function **plot_eigenvectors(i_start=start_i, i_end=end_i)** has 2 parameters which are used for slicing $U$ and the last index is less or equal the total number of eigenvalues

# %%
start_i = 0
end_i = mssa_inst.d # or less !
mssa_inst.plot_eigenvectors(i_start=start_i, i_end=end_i)

# %% [markdown]
# According to the figures above one can notice that the largest contribution of the eigenvalues is associated with the first component $U_0$, whose magnitude decreases monotonously without any oscillations.
#
# This is the trend component.The seasonal component can be associated with $U_1$ to $U_3$ as they demonstrate slight oscillations and their contribution is similar.
#
# The rest components $U_4$ to $U_6$ are associated with the noise component due to lesser contribution and greater fluctuations.

# %% [markdown]
# #### Investigate the Weighted Correlation Matrix

# %% [markdown]
# The weighted correlation matrix is the second tool that help us to assess the correlation between components visually and group the most correlated components together. It reconstructs the time series components from each elementary matrix $X_i$ and measures their correlation.

# %%
mssa_inst.plot_weighted_correlation_matrix()

# %% [markdown]
# According to the figure above, one can pick the first component $X_0$ as the trend, group the components $X_4$ - $X_6$ into the noise component due to their high correlation, while the $X_1$ - $X_3$ components can be separeted into 3 seasonal components because of their moderate correlation, or merged into one. Here we merge them for the simplicity sake.

# %% [markdown]
# ### Component Reconstruction

# %% [markdown]
# Alright, by now we have grouped the elementary matrices into 3 groups:
# - Trend: $X_0$
# - Season: $X_1$
# - Noise:  $X_2$, $X_3$,$X_4$, $X_5$, $X_6$
#
# We can reconstruct the components as follows:

# %% [markdown]
# **Reconstructed Trend**

# %%
trend_comp_ix = [0] # index of the corresponding component, must be either list or numpy.array-> iterable
trend_comp_ts = mssa_inst.reconstruct_ts(idx_chosen_components=trend_comp_ix, return_as_df=True)
trend_comp_ts
# Out:
#        Country       1991       1992       1993       1994       1995  \
# 0       France   8.929274   9.073674   9.233183   9.431762    9.67495
# 1       Canada  10.707913  10.885452  11.094982  11.346115  11.626365
# 2      Germany  12.684623  12.812669  12.956577  13.153797  13.414963
# 3        China  29.499362  30.334485  31.136753  32.007214  32.949904
# 4  Netherlands   3.193258   3.237094   3.285663   3.348707   3.429906
#
#         1996       1997       1998       1999       2000       2001  \
# 0   9.978568  10.324065  10.459425  10.593181  10.849373  11.141331
# 1  11.978558  12.388032  12.549608  12.724616  13.023095  13.355598
# 2  13.757973  14.167327  14.194969  14.223358  14.483387  14.792767
# 3  34.205776  35.815363  37.385139  39.402118  40.883626  42.695498
# 4   3.535268   3.656833   3.699729   3.749605   3.839812   3.946246
#
#         2002       2003       2004       2005
# 0  11.473228  11.859503  12.338447  12.835947
# 1  13.759511  14.245847   14.85311  15.531275
# 2  15.154666  15.601535  16.157969  16.727692
# 3  45.126642   48.30004  52.453275  57.125754
# 4   4.069821    4.21462   4.397887   4.598751

# %% [markdown]
# **Reconstructed Seasonal Component**

# %%
season_comp_ix = [1] # index of the corresponding component, must be either list or numpy.array-> iterable
season_comp_ts = mssa_inst.reconstruct_ts(idx_chosen_components=season_comp_ix, return_as_df=True)
season_comp_ts
# Out:
#        Country      1991      1992      1993      1994      1995      1996  \
# 0       France  0.509705  0.554838   0.57042  0.530285  0.430899  0.270152
# 1       Canada  0.488038  0.618155  0.677732  0.658112  0.571268  0.398194
# 2      Germany   0.92986  1.030717  1.093301  1.037209  0.845692  0.515724
# 3        China  0.001293  0.291541  0.709114  1.158834  1.401296   1.23512
# 4  Netherlands  0.184678  0.209979  0.227591  0.217694  0.177514  0.107061
#
#        1997      1998      1999      2000      2001      2002      2003  \
# 0  0.093658  0.115718  0.126303  0.038348 -0.122928 -0.384828 -0.711257
# 1   0.17149  0.112431  0.081782 -0.052792 -0.269748 -0.525562 -0.785704
# 2  0.137031  0.100029  0.064698 -0.083656 -0.298162 -0.640173  -1.06523
# 3  0.546336 -0.794531 -2.492888 -3.455223 -3.322391 -1.427128  2.487874
# 4   0.02538  0.010353 -0.002396 -0.029982 -0.067828 -0.128191  -0.20269
#
#        2004       2005
# 0 -1.094035  -1.415479
# 1 -1.074078  -1.313301
# 2 -1.597807  -2.123645
# 3  8.365822  13.244636
# 4  -0.28968  -0.358692

# %% [markdown]
# **Reconstructed Noise Component**

# %%
noise_comp_ix = [2,3,4,5,6] # index of the corresponding component, must be either list or numpy.array-> iterable
noise_comp_ts = mssa_inst.reconstruct_ts(idx_chosen_components=noise_comp_ix, return_as_df=True)
noise_comp_ts
# Out:
#        Country      1991      1992      1993      1994      1995      1996  \
# 0       France  0.299062  0.165088 -0.001514 -0.180817 -0.053789   0.17498
# 1       Canada -0.078621 -0.036447 -0.066404  0.019913  0.015617  0.188068
# 2      Germany  0.685217  0.194915  0.022441 -0.178517  0.122805  0.121093
# 3        China -1.342755 -1.359946 -1.812927  0.944413  0.405199  0.113094
# 4  Netherlands  0.117194  0.020807  0.025725  -0.05859 -0.031999   0.09094
#
#        1997      1998      1999      2000      2001      2002      2003  \
# 0 -0.055783  0.014767 -0.004554 -0.037401  0.071257 -0.090451 -0.030406
# 1  0.110158 -0.305049  0.170522  0.106386  -0.20738 -0.126089  0.060468
# 2  0.035883  0.031922 -0.178995 -0.138261  0.124844 -0.189043  0.050906
# 3  1.385621  0.449032  -0.39672 -1.076373 -0.960966  0.210366  0.367517
# 4  0.017178 -0.018572 -0.064749 -0.015659  0.051422  -0.00199  -0.01091
#
#        2004      2005
# 0  0.058678 -0.067948
# 1  0.052249 -0.054234
# 2  0.141318 -0.204548
# 3  2.099933  -2.12472
# 4  0.003743 -0.017729

# %% [markdown]
# Then we can plot the reconstructed components to check the validity of the results. **The sum of the reconstructed time series must converge to the original time series**.
#
# For this purpose we introduce a **full_rec** variable which contains the values of the sum of the reconstructed time series for each country.
#
# One can isolate desired time series, e.g clean the data from the noise by excluding the corressponding reconstructed time series from the sum in **full_rec**.

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(20, 20))
col=["b","r", "g", "c","orange", "purple", "pink", "gray"]
for i in range(train_df.shape[0]):
        plt.plot(   train_df.columns[idx_start:], train_df.iloc[i,idx_start:],ls='solid',alpha=0.4, color=col[i], lw=5,label=f"original {df.iloc[i,0]}" )
        full_rec = np.array([ trend_comp_ts.values[i,idx_start:]]   + season_comp_ts.values[i,idx_start:] + noise_comp_ts.values[i,idx_start:] ).flatten() # contains i-th time series
        plt.plot(train_df.columns[idx_start:], full_rec,    ls=':', color=col[i] ,lw=5, label=f"reconstructed time series of {train_df.iloc[i,0]}")
    
        plt.legend()
        plt.grid()

# %% [markdown]
# ### Forecast Future Values

# %% [markdown]
# It is also possible to use MSSA to predict future values for the multiple time series at once!
# The **MSSA** class in the **py-ssa-lib** implements both **L-Forecast** Method using **Linear Recurrence Relation(LRR)** from $U$ eigenspace, and **K-Forecast** Method using $V$ eigenspace.
#
# Note that for the forecasting values **MSSA** uses the same **LRR** for all time series extracted from the signal subspace.
#
# Therefore, it might be less precise compared to the ordinary **SSA**, which computes the **LRR** for each time series.
# One can predict values for each of the reconstructed component using corresponding indices, or for the original time series.
#
# For example,  we want to forecast $M=3$ values for the *denoised* time series.
#
# For this purpose, we group the trend and the seasonal components together and input indices of the elemenatary components used for their reconstruction as follows:

# %%
denoised_rec_ts = trend_comp_ts.iloc[:, idx_start:] +  season_comp_ts.iloc[:, idx_start:]
denoised_rec_ts = pd.concat([df.iloc[:,0],denoised_rec_ts], axis=1)
denoised_rec_ts
# Out:
#        Country       1991       1992       1993       1994       1995  \
# 0       France   9.798255   9.703343   9.772569   9.880146  10.068685
# 1       Canada  11.148601  11.442638   11.66237  12.057686  12.295628
# 2      Germany  14.274888  13.998928  14.059151   14.12795  14.292216
# 3        China  27.739357  29.391567   30.78261   33.18642  34.810241
# 4  Netherlands   3.511278   3.461902   3.500868   3.536762   3.609475
#
#         1996       1997       1998       1999       2000       2001  \
# 0  10.311269  10.424919  10.583896  10.718644  10.864096  11.036691
# 1  12.462921  12.591309  12.592947  12.860585  12.956812  13.021773
# 2  14.411488  14.339938  14.281107  14.191752  14.279112  14.462365
# 3  36.224948   37.31577  36.938524  36.673141  36.421239  38.342498
# 4   3.690707    3.69709   3.695973   3.706716   3.787217   3.899355
#
#         2002       2003       2004       2005
# 0   11.04109  11.123589  11.275102  11.373521
# 1   13.15897  13.382312  13.882486  14.192141
# 2  14.458127   14.58341  14.642173  14.446893
# 3  43.762516  51.407301  62.725406  68.334489
# 4   3.957414   4.015513   4.095392   4.227263

# %% [markdown]
# **NOTE: By minimizing $MSE$, $MAPE$ or $MAE$ between forecasted values and left out test data,  one can find an optimal combination of the most useful components to decompose(e.g. denoise) time series!**
#
# Because in case of a large number of elementary components or/and time series it is hard to choose components for each time series using graphic tools.

# %% [markdown]
# #### L-Forecast

# %%
M = 3 # number of values to "predict"
idx_denoised = [0,1] # indices of the components
denoised_given_and_future_values =  mssa_inst.L_Forecast(ts = denoised_rec_ts.values[:,idx_start:] , M=M, idx_components=idx_denoised, return_full=True)

# %%
plt.figure(figsize=(20, 20))
plt.grid()
cols = ["red","steelblue", "green", "magenta", "black"]
for i in range(0, min(denoised_rec_ts.shape)):
    plt.plot(denoised_rec_ts.columns[idx_start:], denoised_rec_ts.iloc[i,idx_start:], "-*",c=cols[i], label=f"Reconstructed Time Series of {train_df.iloc[i,0]}");
    plt.plot(df.columns[-M-1:], denoised_given_and_future_values[i,-M-1:], '--o',c=cols[i],label=f"L-Forecast for Reconstructed Time Series of {train_df.iloc[i,0]}");
plt.legend()
plt.xticks(rotation = 90);

# %% [markdown]
# To display only the $M$ predicted values for each of components, we can mask the resulting array as follows:

# %%
idx_ = 0 # or any other index from the idx_denoised
denoised_given_and_future_values[:,-M:]
# Out:
# array([[ 11.63694857,  11.9462107 ,  12.37244494],
#        [ 14.85125297,  15.67210782,  16.74296177],
#        [ 14.64959902,  14.74275731,  14.89856199],
#        [ 83.96845556, 101.4842483 , 123.82001883],
#        [  4.40174071,   4.62275885,   4.92072292]])

# %% [markdown]
# **Or use built-in parameter return_full=False to get only forecasted values**

# %%
M = 3 # number of values to "predict"
idx_denoised = [0,1] # indices of the components
denoised_future_values =  mssa_inst.L_Forecast(ts = denoised_rec_ts.values[:,idx_start:] , M=M, idx_components=idx_denoised, return_full=False)

# %%
denoised_future_values
# Out:
# array([[ 11.63694857,  11.9462107 ,  12.37244494],
#        [ 14.85125297,  15.67210782,  16.74296177],
#        [ 14.64959902,  14.74275731,  14.89856199],
#        [ 83.96845556, 101.4842483 , 123.82001883],
#        [  4.40174071,   4.62275885,   4.92072292]])

# %% [markdown]
# Similarly, we can predict values for each component separately or joinly. However, forecasting noisy data does not make sense

# %% [markdown]
# #### K-Forecast

# %% [markdown]
# It is also possible to forecast future values using $V$ eigenspace, and number of components is limited by  the number of columns of this eigenspace. Number of its columns usually corresponds to a product of $K-1$ and number of time series in the data set.

# %%
M = 3 # number of values to "predict"
idx_K = np.arange(0,45,1)#[0,1] # indices of the components
K_denoised_given_and_future_values =  mssa_inst.K_forecast(ts = denoised_rec_ts.values[:,idx_start:] , M=M, idx_components=idx_K , return_full=True)

# %%
plt.figure(figsize=(20, 20))
plt.grid()
cols = ["red","steelblue", "green", "magenta", "black"]
for i in range(0, min(denoised_rec_ts.shape)):
    plt.plot(denoised_rec_ts.columns[idx_start:], denoised_rec_ts.iloc[i,idx_start:], "-*",c=cols[i], label=f"Reconstructed Time Series of {train_df.iloc[i,0]}");
    plt.plot(df.columns[-M-1:], K_denoised_given_and_future_values[i,-M-1:], '--o',c=cols[i],label=f"K-Forecast for Reconstructed Time Series of {train_df.iloc[i,0]}");
plt.legend()
plt.xticks(rotation = 90);

# %% [markdown]
# #### Compare Test Data vs Forecasts

# %%
plt.figure(figsize=(20, 20))
plt.grid()
cols = ["red","steelblue", "green", "magenta", "black"]
for i in range(0, min(denoised_rec_ts.shape)):
    plt.plot(test_df.columns[-M:], test_df.iloc[i,-M:].values, '-*',c=cols[i],label=f"Test data of {train_df.iloc[i,0]}");
    plt.plot(test_df.columns[-M:], K_denoised_given_and_future_values[i,-M:], '--o',c=cols[i],label=f"K-Forecast for Reconstructed Time Series of {train_df.iloc[i,0]}");
    plt.plot(test_df.columns[-M:], denoised_given_and_future_values[i,-M:], '-.+',c=cols[i],label=f"L-Forecast for Reconstructed Time Series of {train_df.iloc[i,0]}");
plt.legend()
plt.xticks(rotation = 90);

# %% [markdown]
# ### Estimation of the LRR Coefficients

# %% [markdown]
# The L-forecasting method heavily relies on the estimated **LRR-Coefficients**. One can estimate them as follows:

# %%
mssa_inst.estimate_LRR(idx_components= np.arange(mssa_inst.L-1))
# Out:
# array([-3.3847445 ,  5.99750609, -3.7442772 ,  6.48692189, -9.71146441,
#         5.32086201])

# %% [markdown]
# **Note :** the maximal number of used elementary components  should not exceed $L-1$. Otherwise, the verticality coefficient would sum up to 1, which does not yield the correct result.

# %% [markdown]
# ### ESPRIT

# %% [markdown]
# It is also possible to estimate the parameters of the sinusoids comprising the signal by using **ESPRIT** algorithm. The ouptut result represents the complex roots of the characteristic polynom $\mu$, which can be decomposed into real $\omega$ and imaginary $\rho$ components.

# %%
mssa_inst.estimate_ESPRIT(idx_components= np.arange(mssa_inst.L-1), decompose_rho_omega= False)
# Out:
# array([ 2.1020492 +0.71812424j,  2.1020492 -0.71812424j,
#         0.96848353+0.08364295j,  0.96848353-0.08364295j,
#        -0.41010173+0.74681606j, -0.41010173-0.74681606j])

# %% [markdown]
# Again, **note :** the maximal number of used elementary components  should not exceed $L-1$. Otherwise, the result is invalid.
# One can plot the roots on the unit circle as follows:

# %%
mssa_inst.plot_polynomial_roots(idx_components= np.arange(mssa_inst.L-1))
